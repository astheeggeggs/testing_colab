# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/astheeggeggs/testing_colab/blob/main/rare_variant_practical.ipynb)
#
# # LDSC Practical 2 — Genetic Correlation (Colab version)
#
# **MadhurBain Singh, Benjamin Neale**
# **March 5th, 2025**
# **Adapted from Andrew Grotzinger, March 2023**
#
# This notebook is a Colab-friendly rewrite of the original R practical.
# It assumes an **R runtime** in Colab.
#
# **Before you start**
# - Put the practical files in one public Google Drive folder, or upload them into `/content`.
# - Make sure the folder contains the `EUR/` and `EAS/` directories used below.
# - Run the setup cells from top to bottom.

# %%
# Install and initialize udocker
system("pip install -q udocker", intern=TRUE)
system("udocker --allow-root install", intern=TRUE)

# Pull the public image from GHCR (No rate limits!)
system("udocker --allow-root pull ghcr.io/astheeggeggs/saige-workshop:1.5.0", intern=TRUE)

# Verify it runs offline
system("udocker --allow-root run ghcr.io/astheeggeggs/saige-workshop:1.5.0 step1_fitNULLGLMM.R --help", intern=TRUE)
# Out:
# character(0)
# character(0)
# [1] "Info: downloading layer sha256:e1aa896fe21ae437fb0e568861202310d7f62d6d0459cc9b7ae3f3508ce3e3bd"
# [2] "Info: downloading layer sha256:59668c9c4da2e145e6840d86fb1e0ae9f49dc94dc2af28ee638bf189d5fc5d54"
# [3] "Info: downloading layer sha256:dfd71fd4d9d42605c8da41618dd85371745445d2f4b6500492f815e8f586a9fc"
# [4] "Info: downloading layer sha256:27468b860ae4b1b777ecb9711da9d6dfba72d362485e5e9b6204c518f9bfd820"
# [5] "Info: downloading layer sha256:400fe41be45a3c8ac291456dc1cf4be46b698a9e0a7dc309e767de5d266c3419"
# [6] "Info: downloading layer sha256:ea12d88a68cf1d20485f136401b8899ec2c61e0bf3e5ff326f7547731e7a4113"
# [7] "Info: downloading layer sha256:1122dc6eced1dfbfbc92727ea66a6ecab952ade036e064c416ab8ad4ef49f37d"
# [8] "Info: downloading layer sha256:e26a22f9b9b6e38f1359cf127c74eb076f5e09733f76335a2f89265b4e9ad5f2"
# [9] "Info: downloading layer sha256:d7bfe07ed8476565a440c2113cc64d7c0409dba8ef761fb3ec019d7e6b5952df"
#   [1] "R version 4.4.3 (2025-02-28)"
#   [2] "Platform: x86_64-conda-linux-gnu"
#   [3] "Running under: Ubuntu 20.04.4 LTS"
#   [4] ""
#   [5] "Matrix products: default"
#   [6] "BLAS/LAPACK: /app/.pixi/envs/default/lib/libopenblasp-r0.3.30.so;  LAPACK version 3.12.0"
#   [7] ""
#   [8] "locale:"
#   [9] " [1] LC_CTYPE=C.UTF-8       LC_NUMERIC=C           LC_TIME=C.UTF-8       "
#  [10] " [4] LC_COLLATE=C.UTF-8     LC_MONETARY=C.UTF-8    LC_MESSAGES=C.UTF-8   "
#  [11] " [7] LC_PAPER=C.UTF-8       LC_NAME=C              LC_ADDRESS=C          "
#  [12] "[10] LC_TELEPHONE=C         LC_MEASUREMENT=C.UTF-8 LC_IDENTIFICATION=C   "
#  [13] ""
#  [14] "time zone: NA"
#  [15] "tzcode source: system (glibc)"
#  [16] ""
#  [17] "attached base packages:"
#  [18] "[1] stats     graphics  grDevices utils     datasets  methods   base     "
#  [19] ""
#  [20] "other attached packages:"
#  [21] "[1] optparse_1.7.5 SAIGE_1.5.0   "
#  [22] ""
#  [23] "loaded via a namespace (and not attached):"
#  [24] " [1] R6_2.6.1           tidyselect_1.2.1   Matrix_1.7-3       lattice_0.22-7    "
#  [25] " [5] magrittr_2.0.3     splines_4.4.3      getopt_1.20.4      glue_1.8.0        "
#  [26] " [9] tibble_3.3.0       pkgconfig_2.0.3    RcppParallel_5.1.9 dplyr_1.1.4       "
#  [27] "[13] generics_0.1.4     lifecycle_1.0.4    cli_3.6.5          grid_4.4.3        "
#  [28] "[17] vctrs_0.6.5        data.table_1.17.6  compiler_4.4.3     pillar_1.11.0     "
#  [29] "[21] survival_3.8-3     Rcpp_1.1.0         rlang_1.1.6       "
#  [30] "Usage: /usr/local/bin/step1_fitNULLGLMM.R [options]"
#  [31] ""
#  [32] ""
#  [33] "Options:"
#  [34] "\t--plinkFile=PLINKFILE"
#  [35] "\t\tPath to plink file for creating the genetic relationship matrix (GRM). minMAFforGRM can be used to specify the minimum MAF and maxMissingRate can be used to specify the maximum missing rates  of markers in the plink file to be used for constructing GRM. Genetic markers are also randomly selected from the plink file to estimate the variance ratios"
#  [36] ""
#  [37] "\t--bedFile=BEDFILE"
#  [38] "\t\tPath to bed file. If plinkFile is specified, 'plinkFile'.bed will be used"
#  [39] ""
#  [40] "\t--bimFile=BIMFILE"
#  [41] "\t\tPath to bim file. If plinkFile is specified, 'plinkFile'.bim will be used"
#  [42] ""
#  [43] "\t--famFile=FAMFILE"
#  [44] "\t\tPath to fam file. If plinkFile is specified, 'plinkFile'.fam will be used"
#  [45] ""
#  [46] "\t--phenoFile=PHENOFILE"
#  [47] "\t\tRequired. Path to the phenotype file. The file can be either tab or space delimited. The phenotype file has a header and contains at least two columns. One column is for phentoype and the other column is for sample IDs. Additional columns can be included in the phenotype file for covariates in the null model. Please specify the names of the covariates using the argument covarColList and specify categorical covariates using the argument qCovarColList. All categorical covariates must also be included in covarColList."
#  [48] ""
#  [49] "\t--phenoCol=PHENOCOL"
#  [50] "\t\tRequired. Column name for phenotype to be tested in the phenotype file, e.g CAD"
#  [51] ""
#  [52] "\t--traitType=TRAITTYPE"
#  [53] "\t\tRequired. binary or quantitative [default=binary]"
#  [54] ""
#  [55] "\t--eventTimeCol=EVENTTIMECOL"
#  [56] "\t\tfor survival analysis, coloumn name for event time in the phenotype file, e.g eventTime"
#  [57] ""
#  [58] "\t--eventTimeBinSize=EVENTTIMEBINSIZE"
#  [59] "\t\t If specified, event time will be bin by eventTimeBinSize"
#  [60] ""
#  [61] "\t--pcgforUhatforSurvAnalysis=PCGFORUHATFORSURVANALYSIS"
#  [62] "\t\tif survival, whether using pcg in the variance ratio estimation. if FALSE, the exact solve method will be used. Memory usage will be higher [default='TRUE']"
#  [63] ""
#  [64] "\t--invNormalize=INVNORMALIZE"
#  [65] "\t\tOptional. Only for quantitative. Whether to perform the inverse normalization for the phenotype [default='FALSE']"
#  [66] ""
#  [67] "\t--covarColList=COVARCOLLIST"
#  [68] "\t\tList of covariates (comma separated)"
#  [69] ""
#  [70] "\t--qCovarColList=QCOVARCOLLIST"
#  [71] "\t\tList of categorical covariates (comma separated). All categorical covariates must also be in covarColList"
#  [72] ""
#  [73] "\t--sampleIDColinphenoFile=SAMPLEIDCOLINPHENOFILE"
#  [74] "\t\tRequired. Column name of sample IDs in the phenotype file, e.g. IID"
#  [75] ""
#  [76] "\t--tol=TOL"
#  [77] "\t\tOptional. Tolerance for fitting the null GLMM to converge [default=0.02]."
#  [78] ""
#  [79] "\t--maxiter=MAXITER"
#  [80] "\t\tOptional. Maximum number of iterations used to fit the null GLMM [default=20]."
#  [81] ""
#  [82] "\t--tolPCG=TOLPCG"
#  [83] "\t\tOptional. Tolerance for PCG to converge [default=1e-5]."
#  [84] ""
#  [85] "\t--maxiterPCG=MAXITERPCG"
#  [86] "\t\tOptional. Maximum number of iterations for PCG [default=500]."
#  [87] ""
#  [88] "\t--nThreads=NTHREADS"
# ...
# [180] ""
# [181] "\t--MaleOnly=MALEONLY"
# [182] "\t\tOptional. Whether to run Step 1 for males only [default=FALSE]. if TRUE, --sexCol and --MaleCode need to be specified"
# [183] ""
# [184] "\t--sexCol=SEXCOL"
# [185] "\t\tOptional. Column name for sex in the phenotype file, e.g Sex"
# [186] ""
# [187] "\t--FemaleCode=FEMALECODE"
# [188] "\t\tOptional. Values in the column for sex in the phenotype file are used for females [default, '1']"
# [189] ""
# [190] "\t--MaleCode=MALECODE"
# [191] "\t\tOptional. Values in the column for sex in the phenotype file are used for males [default, '0']"
# [192] ""
# [193] "\t--isCovariateOffset=ISCOVARIATEOFFSET"
# [194] "\t\tOptional. Whether to estimate fixed effect coeffciets. [default, 'TRUE']"
# [195] ""
# [196] "\t--SampleIDIncludeFile=SAMPLEIDINCLUDEFILE"
# [197] "\t\tPath to the file that contains one column for IDs of samples who will be include for null model fitting."
# [198] ""
# [199] "\t-h, --help"
# [200] "\t\tShow this help message and exit"
# [201] ""
# [202] ""
# [203] " "
# [204] " ****************************************************************************** "
# [205] " *                                                                            * "
# [206] " *               STARTING fb6a5c7a-cb3b-343f-95f3-2054c1623b04                * "
# [207] " *                                                                            * "
# [208] " ****************************************************************************** "
# [209] " executing: step1_fitNULLGLMM.R"

# %%
system(paste(
  "udocker --allow-root run ghcr.io/astheeggeggs/saige-workshop:1.5.0 createSparseGRM.R",
  "--plinkFile /app/extdata/input/nfam_100_nindep_0_step1_includeMoreRareVariants_poly",
  "--outputPrefix=testsparseGRM --numRandomMarkerforSparseKin=1000 --relatednessCutoff=0.125"), intern=TRUE)

# %% [markdown]
# ## 1) Download the practical files into Colab
#
# Replace `PASTE_PUBLIC_DRIVE_FOLDER_LINK_HERE` with the public folder link that contains the practical files.
# If you already uploaded the files into the runtime, you can skip this cell and set `root_dir` below manually.

# %%
# Install gdown so Colab can fetch a public Google Drive folder
system('python -m pip -q install gdown')

# Replace this with your public Google Drive folder link
drive_folder_url <- "PASTE_PUBLIC_DRIVE_FOLDER_LINK_HERE"

if (grepl("PASTE_PUBLIC_DRIVE_FOLDER_LINK_HERE", drive_folder_url, fixed = TRUE)) {
  message("Replace drive_folder_url with your public Google Drive folder link, then rerun this cell.")
} else {
  system(sprintf('gdown --folder "%s" -O /content/LDSC_Practical_2', drive_folder_url))
  system('find /content/LDSC_Practical_2 -maxdepth 3 -type f | head -50')
}

# %% [markdown]
# ## 2) Environment setup / required packages
#
# This notebook uses an R runtime.
# We install the packages needed for the practical from CRAN and GitHub.
#
# Packages used here:
# - `data.table`
# - `dplyr`
# - `remotes`
# - `GenomicSEM`
# - `corrplot`

# %%
# System libraries that are often useful for R package installation in Colab
system("apt-get update -qq")
system("apt-get install -y -qq libcurl4-openssl-dev libxml2-dev libssl-dev")

# %%
# Install CRAN packages
install.packages(
  c("data.table", "dplyr", "remotes", "corrplot"),
  repos = "https://cloud.r-project.org"
)

# Install GenomicSEM from GitHub
remotes::install_github("GenomicSEM/GenomicSEM", upgrade = "never")

# %% [markdown]
# ### Load packages

# %%
library(data.table)
library(dplyr)
library(GenomicSEM)
library(corrplot)

sessionInfo()

# %% [markdown]
# ## 3) Colab working directory and file helpers
#
# The code below assumes that the practical files are available in `/content/LDSC_Practical_2`.
# If you used the download cell above, that is where the files will be.

# %%
root_dir <- "/content/LDSC_Practical_2"

if (!dir.exists(root_dir)) {
  dir.create(root_dir, recursive = TRUE, showWarnings = FALSE)
}

# Keep paths explicit rather than relying on setwd()
eur_dir <- file.path(root_dir, "EUR")
eas_dir <- file.path(root_dir, "EAS")

# Helper functions for cleaner file previews in notebooks
preview_text <- function(path, n = 10) {
  cat(readLines(path, n = n), sep = "\n")
  cat("\n")
}

preview_gz <- function(path, n = 10) {
  con <- gzfile(path, open = "rt")
  on.exit(close(con), add = TRUE)
  cat(readLines(con, n = n), sep = "\n")
  cat("\n")
}

count_lines <- function(path) {
  length(readLines(path, warn = FALSE))
}

count_gz_lines <- function(path) {
  con <- gzfile(path, open = "rt")
  on.exit(close(con), add = TRUE)
  length(readLines(con, warn = FALSE))
}

list.files(root_dir, recursive = TRUE)[1:min(20, length(list.files(root_dir, recursive = TRUE)))]

# %% [markdown]
# ## Part 1: Continuous traits example in European ancestry
#
# This section uses chromosome 1 summary statistics for BMI and height.

# %% [markdown]
# ### HapMap3 SNPs
#
# As before, we restrict the analyses to high-quality SNPs in the GWAS summary statistics that overlap with the pre-computed LD scores.

# %%
hm3_eur <- file.path(eur_dir, "eur_w_ld_chr", "w_hm3.snplist")

# Take a look at the first few lines
preview_text(hm3_eur)

# Count the number of lines
cat("Number of lines in HM3 file:", count_lines(hm3_eur), "\n")

# %% [markdown]
# **Question:** How many SNPs are there in the HapMap3 reference file?

# %% [markdown]
# ### Step 1: Munge the data

# %%
# Look at the summary statistics files and their columns
preview_text(file.path(eur_dir, "GIANT_UKB_BMI_EUR_chr1.txt"))
preview_text(file.path(eur_dir, "Yengo_Height_EUR_chr1.txt"))

# For multivariate LDSC, specify a vector of file paths with GWAS summary statistics
files_eur <- c(
  file.path(eur_dir, "GIANT_UKB_BMI_EUR_chr1.txt"),
  file.path(eur_dir, "Yengo_Height_EUR_chr1.txt")
)

# Trait names should match the order of the file paths
trait_names_eur <- c("BMI_chr1", "Height_chr1")

# Quality filters
info.filter <- 0.9
maf.filter <- 0.01

munge(
  files = files_eur,
  hm3 = hm3_eur,
  trait.names = trait_names_eur,
  info.filter = info.filter,
  maf.filter = maf.filter
)

# %% [markdown]
# ### Step 2: Run LDSC

# %%
# Examine the munged summary statistics
preview_gz(file.path(eur_dir, "BMI.sumstats.gz"))
preview_gz(file.path(eur_dir, "Height.sumstats.gz"))

traits_eur <- c(
  file.path(eur_dir, "BMI.sumstats.gz"),
  file.path(eur_dir, "Height.sumstats.gz")
)

ld_eur <- file.path(eur_dir, "eur_w_ld_chr")
wld_eur <- file.path(eur_dir, "eur_w_ld_chr")
sample.prev_eur <- c(NA, NA)
population.prev_eur <- c(NA, NA)
trait_names_ldsc_eur <- c("BMI", "Height")

LDSC_EUR <- ldsc(
  traits = traits_eur,
  sample.prev = sample.prev_eur,
  population.prev = population.prev_eur,
  ld = ld_eur,
  wld = wld_eur,
  trait.names = trait_names_ldsc_eur
)

save(LDSC_EUR, file = file.path(eur_dir, "LDSC_EUR.RData"))

# %% [markdown]
# ### Inspect the outputs

# %%
# Genetic covariance matrix
LDSC_EUR$S

# Genetic correlation matrix
cov2cor(LDSC_EUR$S)

# Standard errors from the V matrix
k <- nrow(LDSC_EUR$S)
SE <- matrix(0, k, k)
SE[lower.tri(SE, diag = TRUE)] <- sqrt(diag(LDSC_EUR$V))
SE

# Z-statistics
Z <- LDSC_EUR$S / SE
Z

# P-values
P <- 2 * pnorm(Z, lower.tail = FALSE)
P

# %% [markdown]
# ### Optional: Create an rg heatmap

# %%
rownames(LDSC_EUR$S) <- colnames(LDSC_EUR$S)

corrplot(
  corr = cov2cor(LDSC_EUR$S),
  method = "color",
  addCoef.col = "dark grey",
  add = FALSE,
  bg = "white",
  diag = TRUE,
  outline = TRUE,
  mar = c(0, 0, 2, 0),
  number.cex = 2,
  cl.pos = "b",
  cl.ratio = 0.125,
  cl.align.text = "l",
  cl.offset = 0.2,
  tl.srt = 45,
  tl.pos = "lt",
  tl.offset = 0.2,
  tl.col = "black",
  pch.col = "white",
  addgrid.col = "black",
  xpd = TRUE,
  tl.cex = 1.3,
  is.corr = TRUE,
  title = "European"
)

# %% [markdown]
# ## Part 2: Continuous traits example in East Asian ancestry
#
# The summary statistics and LD scores for this section are from East Asian ancestry.

# %%
# Look at the files
preview_text(file.path(eas_dir, "BMI_EAS_chr1.txt"))
preview_text(file.path(eas_dir, "Yengo_Height_EAS_chr1.txt"))

files_eas <- c(
  file.path(eas_dir, "BMI_EAS_chr1.txt"),
  file.path(eas_dir, "Yengo_Height_EAS_chr1.txt")
)

hm3_eas <- file.path(eas_dir, "eas_ldscores", "w_hm3.snplist")
preview_text(hm3_eas)
cat("Number of lines in EAS HM3 file:", count_lines(hm3_eas), "\n")

trait_names_eas <- c("BMI", "Height")
N_eas <- c(163835, NA)
info.filter <- 0.9
maf.filter <- 0.01

munge(
  files = files_eas,
  hm3 = hm3_eas,
  trait.names = trait_names_eas,
  N = N_eas,
  info.filter = info.filter,
  maf.filter = maf.filter
)

# %%
preview_gz(file.path(eas_dir, "BMI.sumstats.gz"))
preview_gz(file.path(eas_dir, "Height.sumstats.gz"))

traits_eas <- c(
  file.path(eas_dir, "BMI.sumstats.gz"),
  file.path(eas_dir, "Height.sumstats.gz")
)

ld_eas <- file.path(eas_dir, "eas_ldscores")
wld_eas <- file.path(eas_dir, "eas_ldscores")
sample.prev_eas <- c(NA, NA)
population.prev_eas <- c(NA, NA)
trait_names_ldsc_eas <- c("BMI", "Height")

LDSC_EAS <- ldsc(
  traits = traits_eas,
  sample.prev = sample.prev_eas,
  population.prev = population.prev_eas,
  ld = ld_eas,
  wld = wld_eas,
  trait.names = trait_names_ldsc_eas
)

save(LDSC_EAS, file = file.path(eas_dir, "LDSC_EAS.RData"))

# %%
# Genetic covariance matrix
LDSC_EAS$S

# Compare with EUR if needed
load(file.path(eur_dir, "LDSC_EUR.RData"))
LDSC_EUR$S

# Genetic correlation matrix
cov2cor(LDSC_EAS$S)

# Standard errors
k <- nrow(LDSC_EAS$S)
SE <- matrix(0, k, k)
SE[lower.tri(SE, diag = TRUE)] <- sqrt(diag(LDSC_EAS$V))
SE

# Z-statistics
Z <- LDSC_EAS$S / SE
Z

# P-values
P <- 2 * pnorm(Z, lower.tail = FALSE)
P

# %%
rownames(LDSC_EAS$S) <- colnames(LDSC_EAS$S)

corrplot(
  corr = cov2cor(LDSC_EAS$S),
  method = "color",
  addCoef.col = "dark grey",
  add = FALSE,
  bg = "white",
  diag = TRUE,
  outline = TRUE,
  mar = c(0, 0, 2, 0),
  number.cex = 2,
  cl.pos = "b",
  cl.ratio = 0.125,
  cl.align.text = "l",
  cl.offset = 0.2,
  tl.srt = 45,
  tl.pos = "lt",
  tl.offset = 0.2,
  tl.col = "black",
  pch.col = "white",
  addgrid.col = "black",
  xpd = TRUE,
  tl.cex = 1.3,
  is.corr = TRUE,
  title = "East Asian"
)

# %% [markdown]
# ## Part 3: Binary (case/control) traits example in European ancestry

# %%
# Files
preview_text(file.path(eur_dir, "SCZ_chr1.txt"))
preview_text(file.path(eur_dir, "BIP_chr1.txt"))

files_bin <- c(
  file.path(eur_dir, "SCZ_chr1.txt"),
  file.path(eur_dir, "BIP_chr1.txt")
)

hm3_bin <- file.path(eur_dir, "eur_w_ld_chr", "w_hm3.snplist")
trait_names_bin <- c("SCZ", "BIP")
N_bin <- c(NA, NA)
info.filter <- 0.9
maf.filter <- 0.01

munge(
  files = files_bin,
  hm3 = hm3_bin,
  trait.names = trait_names_bin,
  N = N_bin,
  info.filter = info.filter,
  maf.filter = maf.filter
)

# %%
preview_gz(file.path(eur_dir, "SCZ.sumstats.gz"))
preview_gz(file.path(eur_dir, "BIP.sumstats.gz"))

traits_bin <- c(
  file.path(eur_dir, "SCZ.sumstats.gz"),
  file.path(eur_dir, "BIP.sumstats.gz")
)

ld_bin <- file.path(eur_dir, "eur_w_ld_chr")
wld_bin <- file.path(eur_dir, "eur_w_ld_chr")
sample.prev_bin <- c(0.5, 0.5)
population.prev_bin <- c(0.01, 0.02)
trait_names_ldsc_bin <- c("SCZ", "BIP")

LDSC_SCZ_BIP <- ldsc(
  traits = traits_bin,
  sample.prev = sample.prev_bin,
  population.prev = population.prev_bin,
  ld = ld_bin,
  wld = wld_bin,
  trait.names = trait_names_ldsc_bin
)

save(LDSC_SCZ_BIP, file = file.path(eur_dir, "LDSC_SCZ_BIP.RData"))

# %%
# Genetic covariance matrix
LDSC_SCZ_BIP$S

# Genetic correlation matrix
cov2cor(LDSC_SCZ_BIP$S)

# Standard errors
k <- nrow(LDSC_SCZ_BIP$S)
SE <- matrix(0, k, k)
SE[lower.tri(SE, diag = TRUE)] <- sqrt(diag(LDSC_SCZ_BIP$V))
SE

# Z-statistics
Z <- LDSC_SCZ_BIP$S / SE
Z

# P-values
P <- 2 * pnorm(Z, lower.tail = FALSE)
P

# %%
rownames(LDSC_SCZ_BIP$S) <- colnames(LDSC_SCZ_BIP$S)

corrplot(
  corr = cov2cor(LDSC_SCZ_BIP$S),
  method = "color",
  addCoef.col = "dark grey",
  add = FALSE,
  bg = "white",
  diag = TRUE,
  outline = TRUE,
  mar = c(0, 0, 2, 0),
  number.cex = 2,
  cl.pos = "b",
  cl.ratio = 0.125,
  cl.align.text = "l",
  cl.offset = 0.2,
  tl.srt = 45,
  tl.pos = "lt",
  tl.offset = 0.2,
  tl.col = "black",
  pch.col = "white",
  addgrid.col = "black",
  xpd = TRUE,
  tl.cex = 1.3,
  is.corr = TRUE,
  title = "SCZ / BIP"
)

# %% [markdown]
# ## End
#
# You have now run the Colab version of Practical 2 for genetic correlation.
